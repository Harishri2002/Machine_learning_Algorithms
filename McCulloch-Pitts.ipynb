# %%
x1 = [0,0,1,1]
x2 = [0,1,0,1]

output = [0,0,0,1]
print("X2||X2|OP")
for i in range(4):
  yin.append((w1*x[i])+(w2*x2[i]))
print(yin)
print("x1|x2|o/p")
for i in range(4):
  print(x1[i],"|",x2[i],"|",yin[i])
w1=1
w2=1
T=0
print("x1|x2|o/p|activation fx")
for i in range(4):
  y = (w1*x1[i])+(w2*x2[i])
  if y>=1:
    print(x1[i],"|",x2[i],"|",output[i],"|",yin[i],"|",1)
  else:
    print(x1[i])

#NAND

x1 = [0,0,1,1]
x2 = [0,1,0,1]
output = [1,1,1,0]
print("x1|x2|o/p")
for i in range(4):
  print(x1[i],"|",x2[i],"|",output[i])
w1 = 1
w2 = 1
t = 0
yin=[]
for i in range(4):
  yin.append((w1*x[i])+(w2*x2[i]))
print(yin)
print("x1|x2|o/p")
for i in range(4):
  print(x1[i],"|",x2[i],"|",output[i],"|",yin[i])
w1 = 1
w2 = 1
T = 0
print("x1|x2|o/p|activation fx")
for i in range(4):
   y = (w1*x1[i])+(w2*x2[i])
  if y>=T:
    print(x1[i],"|",x2[i],"|",output[i],"|",yin[i],"|",1)
  else:
    print(x1[i])

#OR Gate


x1 = [0,0,1,1]
x2 = [0,1,0,1]
output = [0,1,1,1]
print("x1|x2|o/p")
for i in range(4):
  print(x1[i],"|",x2[i],"|",output[i])
w1 = 1
w2 = 1
t = 0
yin=[]
for i in range(4):
  yin.append((w1*x[i])+(w2*x2[i]))
print(yin)
print("x1|x2|o/p")
for i in range(4):
  print(x1[i],"|",x2[i],"|",output[i],"|",yin[i])
w1 = 1
w2 = 1
T = 0
print("x1|x2|o/p|activation fx")
for i in range(4):
   y = (w1*x1[i])+(w2*x2[i])
  if y>=T:
    print(x1[i],"|",x2[i],"|",output[i],"|",yin[i],"|",1)
  else:
    print(x1[i])

#NOR GATE


x1 = [0,0,1,1]
x2 = [0,1,0,1]
output = [1,0,0,0]
print("x1|x2|o/p")
for i in range(4):
  print(x1[i],"|",x2[i],"|",output[i])
w1 = 1
w2 = 1
t = 0
yin=[]
for i in range(4):
  yin.append((w1*x1[i])+(w2*x2[i]))
print(yin)
print("x1|x2|o/p")
for i in range(4):
  print(x1[i],"|",x2[i],"|",output[i],"|",yin[i])
w1 = 1
w2 = 1
T = 0
print("x1|x2|o/p|activation fx")
for i in range(4):
   y = (w1*x1[i])+(w2*x2[i])
  if y>=T:
    print(x1[i],"|",x2[i],"|",output[i],"|",yin[i],"|",1)
  else:
    print(x1[i])
