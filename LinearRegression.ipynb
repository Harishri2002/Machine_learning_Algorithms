# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/Student_Marks.csv")
df.head()

df.info()
df.shape
df.isnull().sum()

df.dropna(inplace=True)
df.isnull().sum()


df.fillna(df.mean(),inplace=True)
df.isnull().sum()

df.describe()
df.columns

x = df[['number_courses', 'time_study']]
y = df['Marks']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
data = pd.DataFrame({'Actual':y_test,'Predicted:':y_pred})
data.head()

from sklearn.metrics import mean_squared_error,r2_score,mean_absolute_error
print(r2_score(y_test,y_pred))

print("MAE:",mean_absolute_error(y_test,y_pred))
print("MSE:",mean_squared_error(y_test,y_pred))

import matplotlib.pyplot as plt
x_axis = list(range(1,21))
plt.plot(x_axis,y_test,label="Actual",color='red')
plt.plot(x_axis,y_pred,label="Predicted",color='blue')
plt.legend()
plt.show()

from sklearn.svm import SVR
model=SVR()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
data = pd.DataFrame({'Actual':y_test,'Predicted:':y_pred})
data.head()

import matplotlib.pyplot as plt
x_axis = list(range(1,21))
plt.plot(x_axis,y_test,label="Actual",color='red')
plt.plot(x_axis,y_pred,label="Predicted",color='blue')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   number_courses  100 non-null    int64
#  1   time_study      100 non-null    float64
#  2   Marks           100 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB
# 0.9459936100591213
# MAE: 3.0793452296666834
# MSE: 14.200726136374552
